# %%
from influxdb_client import InfluxDBClient
from influxdb_client.client.write_api import SYNCHRONOUS
from InfluxAdmin import *

# %%
import pandas as pd
from datetime import datetime

# %%
client = GetDatabaseClient()

# %%
#Note: startTime ref to now() must be in double quotes
response = QueryDatabase(client=client,startTime=(datetime.strptime("2023-09-20",'%Y-%m-%d')),itemID='453')

# %%
import pytz

# %%
cst = pytz.timezone('America/Chicago')

# %%
(response._time.max()).astimezone(tz=cst)
# Out:
# Timestamp('2023-09-20 21:00:00-0500', tz='America/Chicago')
